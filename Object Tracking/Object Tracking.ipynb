# %% [markdown]
# ## Object Tracking

# %% [markdown]
# ##### Track: Bounding Box
# - Keypoints (Within bounding box)
#     - SIFT + Optical Flow
# - Dynamically Update bounding box location - per frame

# %% [markdown]
# ##### Visualize: Moving Bounding Box
